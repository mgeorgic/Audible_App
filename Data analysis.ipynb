# %%
#import dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import category_encoders as ce
pd.set_option('display.max_rows', None)

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
df1 = pd.read_csv("Data/Audible_Dataset_final.csv")
# Drop the null columns where all values are null
df1 = df1.dropna(axis='columns', how='all')
# Drop the null rows
df1 = df1.dropna()
df1.head()
# Out:
#                     Book Title  \
# 12            The Bomber Mafia
# 22       What Happened to You?
# 23   The Last Thing He Told Me
# 30                     Sapiens
# 31  Never Split the Difference
#
#                                         Book Subtitle        Book Author  \
# 12  A Dream, a Temptation, and the Longest Night o...   Malcolm Gladwell
# 22   Conversations on Trauma, Resilience, and Healing      Oprah Winfrey
# 23                                            A Novel         Laura Dave
# 30                       A Brief History of Humankind  Yuval Noah Harari
# 31         Negotiating as if Your Life Depended on It         Chris Voss
#
#        Book Narrator       Audio Runtime        Audiobook_Type  \
# 12  Malcolm Gladwell   5 hrs and 14 mins  Unabridged Audiobook
# 22    Bruce D. Perry   8 hrs and 27 mins  Unabridged Audiobook
# 23    Rebecca Lowman   8 hrs and 49 mins  Unabridged Audiobook
# 30     Derek Perkins  15 hrs and 17 mins  Unabridged Audiobook
# ...

# %%
counts1 = df1.nunique()
counts1
# Out:
# Book Title              627
# Book Subtitle           530
# Book Author             482
# Book Narrator           443
# Audio Runtime           493
# Audiobook_Type            4
# Categories               21
# Rating                   12
# Total No. of Ratings    611
# Price                   126
# Review 1                611
# Review 2                615
# Review 3                613
# Review 4                612
# Review 5                610
# Review 6                616
# Review 7                615
# Review 8                610
# Review 9                617
# Review 10               615
# Review 11               618
# Review 12               615
# Review 13               619
# Review 14               615
# Review 15               612
# Review 16               619
# Review 17               621
# Review 18               619
# Review 19               619
# Review 20               614
# Review 21               622
# Review 22               623
# Review 23               614
# ...

# %%
train_df=pd.df1({'Categories':['Biographies & Memoirs','Science Fiction & Fantasy',
                               'History','Mystery', 'Thriller & Suspense','Politics & Social Sciences',
                               'Romance','Literature & Fiction','Health & Wellness','Relationships, Parenting & Personal Development']})

# create object of Ordinalencoding
encoder= ce.OrdinalEncoder(cols=['Categories'],return_df=True,
                           mapping=[{'col':'Categories',
'mapping':{'None':0,'Biographies & Memoirs':1,'Science Fiction & Fantasy':2,'History':3,
           'Mystery':4,'Thriller & Suspense':5, 'Politics & Social Sciences':6,  }}])

#Original data
train_df

# %%
df = pd.read_csv("Data/all_english_audible.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#          asin                               author              category  \
# 1  B0052OM9XK                           Simon Pegg  Arts & Entertainment
# 2  B077XN66F8                         Sidney Lumet  Arts & Entertainment
# 3  B00C75YMJ6                       Phil Robertson  Arts & Entertainment
# 4  B00DCD16GE  Robert Greenberg, The Great Courses  Arts & Entertainment
# 5  B0743JMWVB                         Corey Taylor  Arts & Entertainment
#
#                length                                               link  \
# 1   4 hrs and 50 mins  https://www.audible.com/pd/Nerd-Do-Well-Audiob...
# 2   7 hrs and 23 mins  https://www.audible.com/pd/Making-Movies-Audio...
# 3   4 hrs and 57 mins  https://www.audible.com/pd/Happy-Happy-Happy-A...
# 4  24 hrs and 25 mins  https://www.audible.com/pd/How-to-Listen-to-an...
# 5   7 hrs and 51 mins  https://www.audible.com/pd/America-51-Audioboo...
#
#                        narrator  price  rating  rating_count release_date  \
# ...

# %%
counts = df.nunique()
counts
# Out:
# asin            345423
# author          118708
# category            26
# length            2590
# link            428750
# narrator         66037
# price             2206
# rating              10
# rating_count      5110
# release_date      6139
# title           278805
# dtype: int64
